-- %%
%python
df = spark.read.csv("/Volumes/test/landing/raw/recipes.csv",
                    inferSchema=True,
                    header = True,
                    multiLine=True,
                    escape='"')

df.show(5, truncate=False)

-- %%
%python
df.printSchema()

-- %%
%python
df.count()

-- %%
SELECT * FROM test.bronze.raw_recipes;
